# %%
#Variable Naming Conventions
#Snake case,Camel Case,Pascal Case

✅#Variable

#Can't start with a number, can't use spaces, can't
special characters like @,$,!,&

 user_name
 first_name

❌# Can't start with a number
1 name = Irshad

❌# Dash us not Allowed
my_name = Irshad

✅#Valid
name = "Irshad"
_name = "Irshad"
user 1 = "Irshad"

#Use Descriptive Names:
x = 20                 # ❌ Unclear
student_age = 20       # ✅ Clear

✅# Use Snake Case in python
user_name = "Irshad"
total_marks = 70

✅# Use Camel Case in python
user_Name = "Ali"
student_Age = 20

✅#Pascal Case in python
User_Name = "Akram"
Student_Age = 20

✅ IMPORTANT RULE
Pick in Style in all codes
user_name = "Irshad"
